# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/people.xls - people.xls (1).csv')

# %%
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
# Rename the last evaluation column to Performance
# df.rename(columns = {"":""})

# %%
df.rename(columns =
          {"lastEvaluation":"Performance"}, inplace=True)

# %%
df
# Out:
#        satisfactoryLevel  Performance  numberOfProjects  avgMonthlyHours  \
# 0                   0.38         0.53                 2              157
# 1                   0.80         0.86                 5              262
# 2                   0.11         0.88                 7              272
# 3                   0.37         0.52                 2              159
# 4                   0.41         0.50                 2              153
# ...                  ...          ...               ...              ...
# 14994               0.11         0.85                 7              275
# 14995               0.99         0.83                 4              274
# 14996               0.72         0.72                 4              175
# 14997               0.24         0.91                 5              177
# 14998               0.77         0.83                 6              271
#
#        timeSpent.company  workAccident  left  promotionInLast5years  \
# ...

# %%
# EDA (Exploratory data analysis)
# Check head , tail , sample(8)
# check for basic statistics of the data,  null and non- null data(info)
# check for the null values and if found drop it
# check for the duplicates and if found drop the same.

# %%
df.head()
# Out:
#    satisfactoryLevel  Performance  numberOfProjects  avgMonthlyHours  \
# 0               0.38         0.53                 2              157
# 1               0.80         0.86                 5              262
# 2               0.11         0.88                 7              272
# 3               0.37         0.52                 2              159
# 4               0.41         0.50                 2              153
#
#    timeSpent.company  workAccident  left  promotionInLast5years   dept  salary
# 0                  3             0     1                      0  sales     low
# 1                  6             0     1                      0  sales  medium
# 2                  4             0     1                      0  sales  medium
# 3                  3             0     1                      0  sales     low
# 4                  3             0     1                      0  sales     low

# %%
df.tail(9)
# Out:
#        satisfactoryLevel  Performance  numberOfProjects  avgMonthlyHours  \
# 14990               0.73         0.52                 3              274
# 14991               0.85         0.53                 3              250
# 14992               0.30         0.88                 5              245
# 14993               0.61         0.89                 3              242
# 14994               0.11         0.85                 7              275
# 14995               0.99         0.83                 4              274
# 14996               0.72         0.72                 4              175
# 14997               0.24         0.91                 5              177
# 14998               0.77         0.83                 6              271
#
#        timeSpent.company  workAccident  left  promotionInLast5years  \
# 14990                  2             0     0                      0
# 14991                  3             0     0                      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      14999 non-null  float64
#  1   Performance            14999 non-null  float64
#  2   numberOfProjects       14999 non-null  int64
#  3   avgMonthlyHours        14999 non-null  int64
#  4   timeSpent.company      14999 non-null  int64
#  5   workAccident           14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotionInLast5years  14999 non-null  int64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#        satisfactoryLevel   Performance  numberOfProjects  avgMonthlyHours  \
# count       14999.000000  14999.000000      14999.000000     14999.000000
# mean            0.612834      0.716102          3.803054       201.050337
# std             0.248631      0.171169          1.232592        49.943099
# min             0.090000      0.360000          2.000000        96.000000
# 25%             0.440000      0.560000          3.000000       156.000000
# 50%             0.640000      0.720000          4.000000       200.000000
# 75%             0.820000      0.870000          5.000000       245.000000
# max             1.000000      1.000000          7.000000       310.000000
#
#        timeSpent.company  workAccident          left  promotionInLast5years
# count       14999.000000  14999.000000  14999.000000           14999.000000
# mean            3.498233      0.144610      0.238083               0.021268
# ...

# %%
df.isnull().sum()
# Out:
# satisfactoryLevel        0
# Performance              0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(3008)

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#        satisfactoryLevel  Performance  numberOfProjects  avgMonthlyHours  \
# 0                   0.38         0.53                 2              157
# 1                   0.80         0.86                 5              262
# 2                   0.11         0.88                 7              272
# 3                   0.37         0.52                 2              159
# 4                   0.41         0.50                 2              153
# ...                  ...          ...               ...              ...
# 14992               0.30         0.88                 5              245
# 14995               0.99         0.83                 4              274
# 14996               0.72         0.72                 4              175
# 14997               0.24         0.91                 5              177
# 14998               0.77         0.83                 6              271
#
#        timeSpent.company  workAccident  left  promotionInLast5years  \
# ...

# %%
# Which are the unique values in the salary column and give me the count for each values

# %%
df["salary"].value_counts()
# Out:
# salary
# low       5740
# medium    5261
# high       990
# Name: count, dtype: int64

# %%
df["dept"].value_counts()
# Out:
# dept
# sales          3239
# technical      2244
# support        1821
# IT              976
# RandD           694
# product_mng     686
# marketing       673
# accounting      621
# hr              601
# management      436
# Name: count, dtype: int64

# %%
# With parentheses: function
# without: property
# in the help popup, a function is shown with a cube symbol. property is shown with a cuboid symbol.

# %%
# countplot
# sns.countplot
# Try creating a countplot for salary

# %%
sns.countplot(data = df, x="salary", color = "red")
plt.grid(False)
plt.show()

# %%
# Find out if there is a relationship between the no. of project and the employee left

# %%
df["numberOfProjects"].value_counts()
# Out:
# numberOfProjects
# 4    3685
# 3    3520
# 5    2233
# 2    1582
# 6     826
# 7     145
# Name: count, dtype: int64

# %%
sns.countplot(data = df, x= "numberOfProjects",hue = "left",palette=["yellow","red"])
plt.show()

# %%
# hue - differentiating parameter

# %%
# 0 - False(Not left)
# 1 - True(Left)

# %%
# Is department one of the reasons , employees are leaving?
# Find the relationship
# On the top of the bars , i want the exact values...

# %%
sns.countplot(data = df,x="dept",hue="left",palette=["red","black"])
plt.xticks(rotation = 45)
plt.show()

# %%
abc = sns.countplot(data = df,x="dept",hue="left")

for i in abc.containers:
  abc.bar_label(i)

plt.xticks(rotation = 45)
plt.show()

# %%
# Which dept is performing the best in terms of employee retention?
# sales(on a rough note)

# %%
# Find the relation between department and salary

# %%
sns.countplot(data = df,x = "dept",hue = "salary",palette=["blue","green","black"])
plt.xticks(rotation = 45)
plt.show()

# %%
# Find out the relation between  the promotion and the employees who left

# %%
df.columns
# Out:
# Index(['satisfactoryLevel', 'Performance', 'numberOfProjects',
#        'avgMonthlyHours', 'timeSpent.company', 'workAccident', 'left',
#        'promotionInLast5years', 'dept', 'salary'],
#       dtype='object')

# %%
abc = sns.countplot(data=df, x='promotionInLast5years', hue='salary')
for i in abc.containers:
  abc.bar_label(i)
#plt.grid()
plt.xticks(rotation=60)
plt.show()

# %%
abc = sns.countplot(data=df, x='promotionInLast5years', hue='left')
for i in abc.containers:
  abc.bar_label(i)
#plt.grid()
plt.xticks(rotation=60)
plt.show()

# %%
df
# Out:
#        satisfactoryLevel  Performance  numberOfProjects  avgMonthlyHours  \
# 0                   0.38         0.53                 2              157
# 1                   0.80         0.86                 5              262
# 2                   0.11         0.88                 7              272
# 3                   0.37         0.52                 2              159
# 4                   0.41         0.50                 2              153
# ...                  ...          ...               ...              ...
# 14992               0.30         0.88                 5              245
# 14995               0.99         0.83                 4              274
# 14996               0.72         0.72                 4              175
# 14997               0.24         0.91                 5              177
# 14998               0.77         0.83                 6              271
#
#        timeSpent.company  workAccident  left  promotionInLast5years  \
# ...

# %%
# Does salary effect the employees leaving the company?

# %%
abc = sns.countplot(data=df, x='salary', hue='left')
for i in abc.containers:
  abc.bar_label(i)
#plt.grid()
plt.xticks(rotation=60)
plt.show()

# %%
sns.countplot(data = df, x = "timeSpent.company",hue = "left")
plt.show()

# %%
# Plotly
# Can we try ratio of retention for depts?
